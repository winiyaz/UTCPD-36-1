# %% [markdown]
# <div style="background: black; color: #00ff00; padding: 2px; text-align: center;background-size: cover; padding: 10px; text-shadow: 00 0 20px #ec4899">
#     <h1>Day36 - StockTradingAPP</h1>
#
# </div>
#
# 1. [`Colors`](https://rich.readthedocs.io/en/latest/appendix/colors.html?highlight=colors) _ list of standard colors that can be printed out
# 2. [`Ascii Banne Generator`](https://manytools.org/hacker-tools/ascii-banner/) - Used this to generate nice banners below
# 3. [`AsciiFlow`](https://asciiflow.com/#/) - Draw ASCII digrams you can then use this

# %%
# Prettifier # Prettifier
# ------------------------------------------------------
from rich import print as rprint # For rprinting
from rich.pretty import pprint # For pretty printing
from rich import inspect # For inspect
from rich.console import Console # For console.print
from rich.markdown import Markdown # For markdown
from rich.panel import Panel # For Panel()
from rich import box # For Panel Boxes
from rich.prompt import Prompt # For Prompting 
from rich.style import Style # For styles colors
from rich.text import Text # For text Styles
console = Console() # Standard code to access console
from rich.traceback import install
install(show_locals=True)
# -------------------------------------------------------
# Out:
# <bound method InteractiveShell.excepthook of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7cb8941d05e0>>

# %% [markdown]
# # Day 36 Work
#
# 1. Doing some of the work here to get a hang of the API Usage
# 2. Stock trading api looks interesting
# 3. Doing some parts of it
#
# ## Websites
#
# ###  Alphavantage API's
# https://www.alphavantage.co/
# - Mentioned in the course for the API
#
# ### CoinMarketPanty
#
# https://coinmarketcap.com/api/documentation/v1/
# - This is the actual documentattion
# - Smell `c4f0b6a1-ea7e-469b-b536-aae3d0e2efd9`

# %% [markdown]
# # CoinmarketCap Testing

# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'c4f0b6a1-ea7e-469b-b536-aae3d0e2efd9',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  rprint(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  rprint(e)
# Out:
# {
#     'status': {
#         'timestamp': '2024-09-17T00:37:37.497Z',
#         'error_code': 0,
#         'error_message': None,
#         'elapsed': 2,
#         'credit_count': 1,
#         'notice': None,
#         'version': 'V2.0.1'
#     },
#     'data': [
#         {
#             'id': 9204,
#             'name': 'srk3rxzxix',
#             'symbol': 'tf3pww4l8h',
#             'slug': 'edlb2pizufe',
#             'cmc_rank': 2025,
#             'num_market_pairs': 5678,
#             'circulating_supply': 374,
#             'total_supply': 782,
#             'max_supply': 9738,
#             'infinite_supply': None,
#             'last_updated': '2024-09-17T00:37:37.497Z',
#             'date_added': '2024-09-17T00:37:37.497Z',
#             'tags': [
#                 '57i68jw2q9e',
#                 'aq0fk2m99x6',
#                 '5ugsp1cn986',
#                 '6he2evat788',
#                 '786cjquzhhb',
#                 'kyorgdzspe9',
#                 'q13vf60mg7',
#                 'ovc5gntznhm',
#                 's7s95htix3m',
#                 'dcrtl7vj5t'
#             ],
#             'platform': None,
#             'self_reported_circulating_supply': None,
#             'self_reported_market_cap': None,
#             'quote': {
#                 'USD': {
#                     'price': 0.37588798553734004,
#                     'volume_24h': 3650,
#                     'volume_change_24h': 0.5892926648807908,
#                     'percent_change_1h': 0.9809216536902203,
#                     'percent_change_24h': 0.5374928584194207,
#                     'percent_change_7d': 0.40294517094273585,
#                     'market_cap': 0.35050198017463985,
#                     'market_cap_dominance': 9260,
#                     'fully_diluted_market_cap': 0.06268675845380667,
#                     'last_updated': '2024-09-17T00:37:37.497Z'
#                 }
#             }
#         },
#         {
#             'id': 7322,
#             'name': '7u4xglwlnoe',
#             'symbol': '2svbkhcacsa',
#             'slug': 'rx6qormpvb',
#             'cmc_rank': 5816,
#             'num_market_pairs': 9591,
#             'circulating_supply': 8794,
#             'total_supply': 3345,
#             'max_supply': 4377,
#             'infinite_supply': None,
#             'last_updated': '2024-09-17T00:37:37.497Z',
#             'date_added': '2024-09-17T00:37:37.497Z',
#             'tags': [
#                 'mvymbastgrr',
#                 '6wv65hetb1d',
#                 'kglzbr5cyro',
#                 '607t5p7wogv',
#                 '3nj56vg90jn',
#                 'z78vbs06d8',
#                 'zowi03eabnp',
#                 '7xogu3hf718',
#                 '74hu4b4v6dm',
#                 'sqhchiot9ca'
#             ],
#             'platform': None,
#             'self_reported_circulating_supply': None,
#             'self_reported_market_cap': None,
#             'quote': {
#                 'USD': {
#                     'price': 0.550824696196939,
#                     'volume_24h': 258,
#                     'volume_change_24h': 0.27810189716615397,
#                     'percent_change_1h': 0.4557955512024827,
#                     'percent_change_24h': 0.5101606478116398,
#                     'percent_change_7d': 0.8513128980288827,
#                     'market_cap': 0.8087174391811345,
#                     'market_cap_dominance': 6844,
#                     'fully_diluted_market_cap': 0.9901802080028923,
#                     'last_updated': '2024-09-17T00:37:37.497Z'
#                 }
#             }
#         },
#         {
#             'id': 7574,
#             'name': 'knph9maezl',
#             'symbol': 'tic5jugt2wr',
#             'slug': 'pt99pock2hq',
#             'cmc_rank': 6211,
#             'num_market_pairs': 3012,
#             'circulating_supply': 1897,
#             'total_supply': 8392,
#             'max_supply': 3307,
#             'infinite_supply': None,
#             'last_updated': '2024-09-17T00:37:37.497Z',
#             'date_added': '2024-09-17T00:37:37.497Z',
#             'tags': [
#                 'eloaruf2i8e',
#                 '7lufhp6l1o5',
#                 '7kqqcqhdt5',
#                 '5l0anbhashn',
#                 'wko1ii6ss9k',
#                 '5fpgg8fp7au',
#                 '70qktmj2jeq',
#                 '3q6wd1s78bk',
#                 'i2wn6ljnrko',
#                 'ibmc7ds3xt'
#             ],
#             'platform': None,
#             'self_reported_circulating_supply': None,
#             'self_reported_market_cap': None,
#             'quote': {
#                 'USD': {
#                     'price': 0.4635615266316706,
#                     'volume_24h': 1694,
#                     'volume_change_24h': 0.6850236592245009,
#                     'percent_change_1h': 0.697008515899576,
#                     'percent_change_24h': 0.8574034898999137,
#                     'percent_change_7d': 0.4280774614447105,
#                     'market_cap': 0.6265055046138084,
#                     'market_cap_dominance': 903,
#                     'fully_diluted_market_cap': 0.7959666833034109,
#                     'last_updated': '2024-09-17T00:37:37.497Z'
#                 }
#             }
#         },
#         {
#             'id': 605,
#             'name': 'vlpgquum719',
#             'symbol': '0neulu5omwl',
#             'slug': 'd3v732mm4nm',
#             'cmc_rank': 2086,
#             'num_market_pairs': 2545,
#             'circulating_supply': 6789,
#             'total_supply': 3908,
#             'max_supply': 5311,
#             'infinite_supply': None,
#             'last_updated': '2024-09-17T00:37:37.497Z',
#             'date_added': '2024-09-17T00:37:37.497Z',
#             'tags': [
#                 'k9uz5c4ibls',
#                 'nallcelaxy',
#                 'lm9ly6g8zjg',
#                 'zabat4vccg',
#                 'o84d5zebdpg',
#                 'neltulctfd',
#                 '9emc107xcck',
#                 'usd56e4g7b',
#                 '4u850luawv2',
#                 'lq2qnrn6qk'
#             ],
#             'platform': None,
#             'self_reported_circulating_supply': None,
#             'self_reported_market_cap': None,
#             'quote': {
#                 'USD': {
#                     'price': 0.6267180556333873,
#                     'volume_24h': 3221,
#                     'volume_change_24h': 0.23525247641095182,
#                     'percent_change_1h': 0.4371843345688715,
#                     'percent_change_24h': 0.8334283263129079,
#                     'percent_change_7d': 0.5684224568333334,
#                     'market_cap': 0.3464369906279725,
#                     'market_cap_dominance': 8899,
#                     'fully_diluted_market_cap': 0.21282858266471982,
#                     'last_updated': '2024-09-17T00:37:37.497Z'
#                 }
#             }
#         },
#         {
#             'id': 6001,
#             'name': 'bycxjdx3fdu',
#             'symbol': '4tm4kb2338g',
#             'slug': '8rf0plwkad6',
#             'cmc_rank': 4146,
#             'num_market_pairs': 9718,
#             'circulating_supply': 9706,
#             'total_supply': 1343,
#             'max_supply': 9722,
#             'infinite_supply': None,
#             'last_updated': '2024-09-17T00:37:37.497Z',
#             'date_added': '2024-09-17T00:37:37.497Z',
#             'tags': [
#                 'knh1t9pr7lj',
#                 '4in97a0h8uu',
#                 's5hsqzbmrj',
#                 'enag96zsn0l',
#                 'xdvpa7i6zke',
#                 'l41mztwsd1e',
#                 'wwa1lx28uh',
#                 'c5yqm930job',
#                 '5o471el5ziu',
#                 'ooshjl0biz'
#             ],
#             'platform': None,
#             'self_reported_circulating_supply': None,
#             'self_reported_market_cap': None,
#             'quote': {
#                 'USD': {
#                     'price': 0.3559253052159834,
#                     'volume_24h': 749,
#                     'volume_change_24h': 0.9785694716026756,
#                     'percent_change_1h': 0.5757358646009627,
#                     'percent_change_24h': 0.3180611396904509,
#                     'percent_change_7d': 0.38868041409289456,
#                     'market_cap': 0.5428081416059396,
#                     'market_cap_dominance': 7409,
#                     'fully_diluted_market_cap': 0.05505993649262675,
#                     'last_updated': '2024-09-17T00:37:37.497Z'
#                 }
#             }
#         },
#         {
#             'id': 5019,
#             'name': 'quy6u1z9ube',
#             'symbol': 'e3c5nsza17u',
#             'slug': 'fkh6enpw9f4',
#             'cmc_rank': 7587,
#             'num_market_pairs': 7461,
#             'circulating_supply': 3704,
#             'total_supply': 8067,
#             'max_supply': 8598,
#             'infinite_supply': None,
#             'last_updated': '2024-09-17T00:37:37.497Z',
#             'date_added': '2024-09-17T00:37:37.497Z',
#             'tags': [
#                 'z0sg47loer',
#                 '1s9ed4q3098',
#                 '78rdwzfu3hq',
#                 '484u7dwf734',
#                 'vn6kc25e4s',
#                 'ntlx9bl1ozd',
#                 'v0loa9rq0p',
#                 '2igcwbtm9fr',
#                 'mef819q3dvs',
#                 'tkkis94h5c'
#             ],
#             'platform': None,
#             'self_reported_circulating_supply': None,
#             'self_reported_market_cap': None,
#             'quote': {
#                 'USD': {
#                     'price': 0.10640970908481506,
#                     'volume_24h': 7724,
#                     'volume_change_24h': 0.23009167816339038,
#                     'percent_change_1h': 0.48017961052600433,
#                     'percent_change_24h': 0.26363396806096406,
#                     'percent_change_7d': 0.8841565678749275,
#                     'market_cap': 0.2849525110057469,
#                     'market_cap_dominance': 3634,
#                     'fully_diluted_market_cap': 0.6731029421349293,
#                     'last_updated': '2024-09-17T00:37:37.497Z'
#                 }
#             }
#         },
#         {
#             'id': 5886,
#             'name': '5jy29d7dlde',
#             'symbol': '3ctqceadcg4',
#             'slug': 'h0nxenb89v5',
#             'cmc_rank': 6649,
#             'num_market_pairs': 5778,
#             'circulating_supply': 5809,
#             'total_supply': 4628,
#             'max_supply': 4533,
#             'infinite_supply': None,
#             'last_updated': '2024-09-17T00:37:37.497Z',
#             'date_added': '2024-09-17T00:37:37.497Z',
#             'tags': [
#                 'tix2v3p9lo',
#                 '2qcfhvtn5pg',
#                 'pk11ix2t6jc',
#                 'mocrp0fqyw',
#                 'kgywr4wvtt',
#                 '1bs4vzq18a5',
#                 'gt955zpv94',
#                 '6xl3317y4ic',
#                 'blja518d0w',
#                 '0lki7jtg4m'
#             ],
#             'platform': None,
#             'self_reported_circulating_supply': None,
#             'self_reported_market_cap': None,
#             'quote': {
#                 'USD': {
#                     'price': 0.28415836325062394,
#                     'volume_24h': 2811,
#                     'volume_change_24h': 0.7510599862123257,
#                     'percent_change_1h': 0.5388504333133886,
#                     'percent_change_24h': 0.01248267782894108,
#                     'percent_change_7d': 0.5740387552441166,
#                     'market_cap': 0.6453905352359188,
#                     'market_cap_dominance': 8106,
#                     'fully_diluted_market_cap': 0.9994922379879358,
#                     'last_updated': '2024-09-17T00:37:37.497Z'
#                 }
#             }
#         },
#         {
#             'id': 8945,
#             'name': '378z0fx01lp',
#             'symbol': '70ug57pnvfq',
#             'slug': 'qsv5hohblre',
#             'cmc_rank': 8812,
#             'num_market_pairs': 7422,
#             'circulating_supply': 9031,
#             'total_supply': 1082,
#             'max_supply': 136,
#             'infinite_supply': None,
#             'last_updated': '2024-09-17T00:37:37.497Z',
#             'date_added': '2024-09-17T00:37:37.497Z',
#             'tags': [
#                 '553zmmz5zqu',
#                 'e8l1pm9bris',
#                 'chzf69gwshf',
#                 'j86hx639blb',
#                 'zheogh1zw2l',
#                 'quwybpwgz7',
#                 'bepbjvfsemc',
#                 'gm85kc73xb',
#                 'zswrlu5kevs',
#                 'o9d7uqmu34'
#             ],
#             'platform': None,
#             'self_reported_circulating_supply': None,
#             'self_reported_market_cap': None,
#             'quote': {
#                 'USD': {
#                     'price': 0.673936008756038,
#                     'volume_24h': 9272,
#                     'volume_change_24h': 0.5196180068362635,
#                     'percent_change_1h': 0.16926327496357452,
#                     'percent_change_24h': 0.7362315739310505,
#                     'percent_change_7d': 0.7878600799522504,
#                     'market_cap': 0.2685671080988936,
#                     'market_cap_dominance': 6740,
#                     'fully_diluted_market_cap': 0.20352350005064723,
#                     'last_updated': '2024-09-17T00:37:37.497Z'
#                 }
#             }
#         },
#         {
#             'id': 5279,
#             'name': 'w8lqb6a76h7',
#             'symbol': 'hzwx3j2mams',
#             'slug': 'jjamn0nnh9',
#             'cmc_rank': 7677,
#             'num_market_pairs': 46,
#             'circulating_supply': 395,
#             'total_supply': 5333,
#             'max_supply': 2834,
#             'infinite_supply': None,
#             'last_updated': '2024-09-17T00:37:37.497Z',
#             'date_added': '2024-09-17T00:37:37.497Z',
#             'tags': [
#                 'zx9en9ovc6q',
#                 'u9v9rmodhg',
#                 '2kbisin7xyf',
#                 'csvk0072mzn',
#                 'kz5j731pb68',
#                 '8r1ngakeb2s',
#                 '6ffhskh8add',
#                 'ntm0xwbffaq',
#                 'k0m8cskhqqc',
#                 '96gyc73ni7'
#             ],
#             'platform': None,
#             'self_reported_circulating_supply': None,
#             'self_reported_market_cap': None,
#             'quote': {
#                 'USD': {
#                     'price': 0.2383602792877797,
#                     'volume_24h': 6651,
#                     'volume_change_24h': 0.42549323834474384,
#                     'percent_change_1h': 0.25425333145122475,
#                     'percent_change_24h': 0.46726791299699233,
#                     'percent_change_7d': 0.7360766580823106,
#                     'market_cap': 0.8543741783532419,
#                     'market_cap_dominance': 5055,
#                     'fully_diluted_market_cap': 0.5120824392840402,
#                     'last_updated': '2024-09-17T00:37:37.497Z'
#                 }
#             }
#         },
#         {
#             'id': 7212,
#             'name': 'fqnkutp82kt',
#             'symbol': 'auc2a8oafzs',
#             'slug': '8xehfc320xg',
#             'cmc_rank': 2923,
#             'num_market_pairs': 138,
#             'circulating_supply': 2271,
#             'total_supply': 3271,
#             'max_supply': 3141,
#             'infinite_supply': None,
#             'last_updated': '2024-09-17T00:37:37.497Z',
#             'date_added': '2024-09-17T00:37:37.497Z',
#             'tags': [
#                 '11ypaogq5zmb',
#                 'eo8y7e9wi8j',
#                 'z9fz3kev1xa',
#                 'g0gq0fp61fb',
#                 'wqfz8qqr8i',
#                 'gy3rl07hmov',
#                 'o32z32obnln',
#                 '48ufdn9xbl9',
#                 'i8cwnqa7ysi',
#                 '00lrt41of04p'
#             ],
#             'platform': None,
#             'self_reported_circulating_supply': None,
#             'self_reported_market_cap': None,
#             'quote': {
#                 'USD': {
#                     'price': 0.28550753401847895,
#                     'volume_24h': 5333,
#                     'volume_change_24h': 0.5562754049777423,
#                     'percent_change_1h': 0.7946184638459628,
#                     'percent_change_24h': 0.10841719748911083,
#                     'percent_change_7d': 0.46198185110050516,
#                     'market_cap': 0.5987217373925571,
#                     'market_cap_dominance': 4494,
#                     'fully_diluted_market_cap': 0.9747247788100835,
#                     'last_updated': '2024-09-17T00:37:37.497Z'
#                 }
#             }
#         }
#     ]
# }
